# %%
from preprocess import preprocess

# %%
preprocess()
# Out:
# start preprocess
# start at 2017/11/17 14:18:50
# 6 total, 4 processed
# LKDS-00052 handled
# LKDS-00299 handled
# LKDS-00359 handled
# LKDS-00389 handled
# 1 process ./dataset/correct_images/LKDS-00390.mhd
# origin
# binary
# clear_border
# keep 2 lagest connected graph
# closing
# dilation
# final
# {'seriesuid': 'LKDS-00390', 'shape': (512, 512, 244), 'origin': array([ 136.6,  144.8, -294. ]), 'spacing': array([ 0.70117199,  0.70117199,  1.25      ]), 'pixels': 11036505, 'cover_ratio': 0.17254477641621574, 'process_duration': 52.67975902557373}
# 2 process ./dataset/correct_images/LKDS-00893.mhd
# origin
# binary
# clear_border
# keep 2 lagest connected graph
# closing
# dilation
# final
# {'seriesuid': 'LKDS-00893', 'shape': (512, 512, 205), 'origin': array([ 167.2 ,  155.  , -307.25]), 'spacing': array([ 0.60546899,  0.60546899,  1.25      ]), 'pixels': 9039352, 'cover_ratio': 0.16820678710937501, 'process_duration': 46.10516309738159}
# all preprocess done
